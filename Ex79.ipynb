# %% [markdown]
# Voici le programme de l'exercice 79. Il est à compléter, puis à exécuter avec n=6. Il faudra pour cela (une fois le programme modifié) cliquer sur le bouton "play" puis saisir dans la ligne suivante Balayage(6) puis cliquer à nouveau sur le bouton "play".

# %%
def f(x):
    y=
    return y

def Balayage(n):
    s=3
    while f(s)<=     :
        s=s+10**(-n)
    s=round(s,n)
    t=round(f(s),n)
    return t,s
